# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Age':[25,30,np.nan,40,30],
    'Department':["HR","Finance","Finance",np.nan,'IT']})
print("Original DataSet(With Missing Values): ")
print(df)
df['Age']=df['Age'].fillna(df['Age'].mean())
df['Department']=df['Department'].fillna(df['Department'].mode()[0]);
print("\nDataset After Handling Missing Values: ")
print(df)
# Out:
# Original DataSet(With Missing Values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  30.0         IT
#
# Dataset After Handling Missing Values:
#      Age Department
# 0  25.00         HR
# 1  30.00    Finance
# 2  31.25    Finance
# 3  40.00    Finance
# 4  30.00         IT

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Age':[25,30,np.nan,40,30],
    'Department':["HR","Finance","Finance",np.nan,'IT']})
print("Original DataSet(With Missing Values): ")
print(df)
df_ffill=df.copy()
df_ffill.ffill(inplace=True)
print(df_ffill)
df_bfill=df.copy()
df_bfill.bfill(inplace=True)
print(df_bfill)
# Out:
# Original DataSet(With Missing Values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0        NaN
# 4  30.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  30.0    Finance
# 3  40.0    Finance
# 4  30.0         IT
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2  40.0    Finance
# 3  40.0         IT
# 4  30.0         IT

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'Age':[25,30,np.nan,40,30],
    'Department':["HR","Finance","Finance",'IT','IT']})
print("Original DataSet(With Missing Values): ")
print(df)

df_drop_rows=df.dropna()
print("After Dropping The Rows: \n",df_drop_rows)
df_drop_cols=df.dropna(axis=1)
print("After Dropping The Cols: \n",df_drop_cols)
# Out:
# Original DataSet(With Missing Values):
#     Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 2   NaN    Finance
# 3  40.0         IT
# 4  30.0         IT
# After Dropping The Rows:
#      Age Department
# 0  25.0         HR
# 1  30.0    Finance
# 3  40.0         IT
# 4  30.0         IT
# After Dropping The Cols:
#    Department
# 0         HR
# 1    Finance
# 2    Finance
# 3         IT
# 4         IT

# %%
import pandas as pd
df = pd.DataFrame({
    'ID': [1, 2, 3, 4, 5],
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve']
})
print("Original Data:\n", df)
df_exact = df.drop_duplicates()
print("\nAfter Exact Match Removal:\n", df_exact)
# Out:
# Original Data:
#     ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David
# 4   5      Eve
#
# After Exact Match Removal:
#     ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4    David
# 4   5      Eve

# %%
df=pd.DataFrame({
    'ID':[1,2,2,3,4,4],
    'Name':['Alice','Bob','Bob','Charlie','David','David'],
    'Age':[25,30,30,35,40,40]
    })
print("Original DataSet(With Missing Values): ")
print(df)
df_subset_id=df.drop_duplicates(subset=["ID"])
print("\nAfter Subset-Based Removal (ID): \n",df_subset_id)
df_subset_name=df.drop_duplicates(subset=["Name"])
print("\nAfter Subset-Based Removal (Name): \n",df_subset_name)
# Out:
# Original DataSet(With Missing Values):
#    ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 2   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
# 5   4    David   40
#
# After Subset-Based Removal (ID):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
#
# After Subset-Based Removal (Name):
#     ID     Name  Age
# 0   1    Alice   25
# 1   2      Bob   30
# 3   3  Charlie   35
# 4   4    David   40
